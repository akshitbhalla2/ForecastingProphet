# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
# import random
import seaborn as sns
from fbprophet import Prophet
# Out:
# /home/akshitbhalla/anaconda3/lib/python3.7/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
df = pd.read_csv("avocado.csv")

# %% [markdown]
# - Date: The date of the observation
# - AveragePrice: the average price of a single avocado
# - type: conventional or organic
# - year: the year
# - Region: the city or region of the observation
# - Total Volume: Total number of avocados sold
# - 4046: Total number of avocados with PLU 4046 sold
# - 4225: Total number of avocados with PLU 4225 sold
# - 4770: Total number of avocados with PLU 4770 sold

# %%
df
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0               0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4  2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 18244           7  2018-02-04          1.63      17074.83  2046.96    1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70    3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92    2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63    2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77    2356.13
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    18249 non-null  int64
#  1   Date          18249 non-null  object
#  2   AveragePrice  18249 non-null  float64
#  3   Total Volume  18249 non-null  float64
#  4   4046          18249 non-null  float64
#  5   4225          18249 non-null  float64
#  6   4770          18249 non-null  float64
#  7   Total Bags    18249 non-null  float64
#  8   Small Bags    18249 non-null  float64
#  9   Large Bags    18249 non-null  float64
#  10  XLarge Bags   18249 non-null  float64
#  11  type          18249 non-null  object
#  12  year          18249 non-null  int64
#  13  region        18249 non-null  object
# dtypes: float64(9), int64(2), object(3)
# memory usage: 1.9+ MB

# %%
df["Date"] = pd.to_datetime(df["Date"], format = "%Y-%m-%d")
df = df.sort_values(["Date"])

# %%
df.describe()
# Out:
#          Unnamed: 0  AveragePrice  Total Volume          4046          4225  \
# count  18249.000000  18249.000000  1.824900e+04  1.824900e+04  1.824900e+04
# mean      24.232232      1.405978  8.506440e+05  2.930084e+05  2.951546e+05
# std       15.481045      0.402677  3.453545e+06  1.264989e+06  1.204120e+06
# min        0.000000      0.440000  8.456000e+01  0.000000e+00  0.000000e+00
# 25%       10.000000      1.100000  1.083858e+04  8.540700e+02  3.008780e+03
# 50%       24.000000      1.370000  1.073768e+05  8.645300e+03  2.906102e+04
# 75%       38.000000      1.660000  4.329623e+05  1.110202e+05  1.502069e+05
# max       52.000000      3.250000  6.250565e+07  2.274362e+07  2.047057e+07
#
#                4770    Total Bags    Small Bags    Large Bags    XLarge Bags  \
# count  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04   18249.000000
# mean   2.283974e+04  2.396392e+05  1.821947e+05  5.433809e+04    3106.426507
# ...

# %%
plt.figure(figsize = (10, 5))
plt.plot(df["Date"], df["AveragePrice"])

# %%
plt.figure(figsize = (10, 6))
sns.distplot(df["AveragePrice"])
# Out:
# <AxesSubplot:xlabel='AveragePrice'>

# %%
sns.violinplot(df["AveragePrice"], df["type"])
# Out:
# <AxesSubplot:xlabel='AveragePrice', ylabel='type'>

# %%
plt.figure(figsize=[25,12])
sns.countplot(x = 'region', data = df)
plt.xticks(rotation = 45)
plt.show()

# %%
plt.figure(figsize=[10, 5])
sns.countplot(x = 'year', data = df)
plt.xticks(rotation = 45)
plt.show()

# %%
sns.catplot(
    "AveragePrice", 
    "region", 
    data = df[df["type"] == "conventional"],
    hue = "year",
    height = 20
)
plt.show()

# %%
sns.catplot(
    "AveragePrice", 
    "region", 
    data = df[df["type"] == "organic"],
    hue = "year",
    height = 20
)
plt.show()

# %% [markdown]
# # Prophet

# %%
df_prophet = df[["Date", "AveragePrice"]]

# %%
df_prophet = df_prophet.rename(columns = {
    "Date": "ds",
    "AveragePrice": "y"
})

# %%
df_prophet
# Out:
#               ds     y
# 11569 2015-01-04  1.75
# 9593  2015-01-04  1.49
# 10009 2015-01-04  1.68
# 1819  2015-01-04  1.52
# 9333  2015-01-04  1.64
# ...          ...   ...
# 8574  2018-03-25  1.36
# 9018  2018-03-25  0.70
# 18141 2018-03-25  1.42
# 17673 2018-03-25  1.70
# 8814  2018-03-25  1.34
#
# [18249 rows x 2 columns]

# %%
model = Prophet()
model = model.fit(df_prophet)
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 8 threads.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
future = model.make_future_dataframe(periods = 365)
forecast = model.predict(future)

# %%
forecast
# Out:
#               ds     trend  yhat_lower  yhat_upper  trend_lower  trend_upper  \
# 0     2015-01-04  1.496497    0.862482    1.871057     1.496497     1.496497
# 1     2015-01-04  1.496497    0.919719    1.857350     1.496497     1.496497
# 2     2015-01-04  1.496497    0.911026    1.836265     1.496497     1.496497
# 3     2015-01-04  1.496497    0.890385    1.861065     1.496497     1.496497
# 4     2015-01-04  1.496497    0.907412    1.899541     1.496497     1.496497
# ...          ...       ...         ...         ...          ...          ...
# 18609 2019-03-21  1.161789    0.525337    1.604947     0.972355     1.346617
# 18610 2019-03-22  1.161059    0.533378    1.605526     0.970884     1.346911
# 18611 2019-03-23  1.160328    0.546061    1.628918     0.969423     1.346364
# 18612 2019-03-24  1.159597    0.550640    1.617927     0.967139     1.346224
# 18613 2019-03-25  1.158867    0.571239    1.607177     0.965529     1.346082
#
# ...

# %%
model.plot(forecast, xlabel = "Date", ylabel = "Price")

# %%
model.plot_components(forecast)

# %%
df_west = df[df["region"] == "West"]

# %%
df_west_prophet = df_west[["Date", "AveragePrice"]]

# %%
plt.figure(figsize = (10, 5))
plt.plot(df_west_prophet["Date"], df_west_prophet["AveragePrice"])
plt.show()

# %%
df_west_prophet = df_west.rename(columns = {
    "Date": "ds",
    "AveragePrice": "y"
})

# %%
model = Prophet()
model = model.fit(df_west_prophet)

future = model.make_future_dataframe(periods=365)
forecast = model.predict(future)
# Out:
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
model.plot(forecast, xlabel='Date', ylabel='Price')

# %%
model.plot_components(forecast)
plt.show()

# %%
avocado_df = pd.read_csv('avocado.csv')
avocado_df.head()
avocado_df.tail(5)
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046     4225  \
# 18244           7  2018-02-04          1.63      17074.83  2046.96  1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70  3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92  2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63  2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77  2356.13
#
#          4770  Total Bags  Small Bags  Large Bags  XLarge Bags     type  year  \
# 18244    0.00    13498.67    13066.82      431.85          0.0  organic  2018
# 18245    0.00     9264.84     8940.04      324.80          0.0  organic  2018
# 18246  727.94     9394.11     9351.80       42.31          0.0  organic  2018
# 18247  727.01    10969.54    10919.54       50.00          0.0  organic  2018
# 18248  224.53    12014.15    11988.14       26.01          0.0  organic  2018
#
#                  region
# ...
